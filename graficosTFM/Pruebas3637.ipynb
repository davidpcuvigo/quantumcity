# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df36a = pd.read_csv('prueba36a.csv',delimiter=',',index_col=3)
df36b = pd.read_csv('prueba36b.csv',delimiter=',',index_col=3)
df37a = pd.read_csv('prueba37a.csv',delimiter=',',index_col=3)
df37b = pd.read_csv('prueba37b.csv',delimiter=',',index_col=3)

# %%
#Fidelity
dfGraf = pd.concat([df36a['Mean fidel'],df36b['Mean fidel'],
                                         df37a['Mean fidel'],df37b['Mean fidel']],axis=1)

dfGraf.columns=['Demanda alta - Oldest','Demanda baja - Oldest','Demanda alta - Newest','Demanda baja - Newest']
fig = plt.figure(figsize=(6,3))
_ = dfGraf['Demanda alta - Oldest'].plot(color='b',legend='True')
_ = dfGraf['Demanda baja - Oldest'].plot(color='r',legend='True')
_ = dfGraf['Demanda alta - Newest'].plot(color='g',legend='True')
_ = dfGraf['Demanda baja - Newest'].plot(color='y',legend='True')
plt.title('Evolución de la fidelidad con el tiempo \n de ejecución instrucciones')
plt.xlabel('nanosegundos')
plt.ylabel('Fidelidad')
# Out:
# Text(0, 0.5, 'Fidelidad')

# %%
#Mean time
dfGraf = pd.concat([df36a['Mean time'],df36b['Mean time'],
                                         df37a['Mean time'],df37b['Mean time']],axis=1)

dfGraf.columns=['Demanda alta - Oldest','Demanda baja - Oldest','Demanda alta - Newest','Demanda baja - Newest']
fig = plt.figure(figsize=(6,3))
_ = dfGraf['Demanda alta - Oldest'].plot(color='b',legend='True')
_ = dfGraf['Demanda baja - Oldest'].plot(color='r',legend='True')
_ = dfGraf['Demanda alta - Newest'].plot(color='g',legend='True')
_ = dfGraf['Demanda baja - Newest'].plot(color='y',legend='True')
plt.axis([10, 100, 525000, 536000])
plt.title('Evolución del tiempo medio de teleportación \n de ejecución instrucciones')
plt.xlabel('nanosegundos')
plt.ylabel('Fidelidad')
# Out:
# Text(0, 0.5, 'Fidelidad')

# %%
#Teleported states
dfGraf = pd.concat([df36a['Teleported states'],df36b['Teleported states'],
                                         df37a['Teleported states'],df37b['Teleported states']],axis=1)

dfGraf.columns=['Demanda alta - Oldest','Demanda baja - Oldest','Demanda alta - Newest','Demanda baja - Newest']
fig = plt.figure(figsize=(6,3))
_ = dfGraf['Demanda alta - Oldest'].plot(color='b',legend='True')
_ = dfGraf['Demanda baja - Oldest'].plot(color='r',legend='True')
_ = dfGraf['Demanda alta - Newest'].plot(color='g',legend='True')
_ = dfGraf['Demanda baja - Newest'].plot(color='y',legend='True')
plt.title('Evolución de estados teleportados con el \n tiempo de ejecución de instrucciones')
plt.xlabel('nanosegundos')
plt.ylabel('estados teleportados')
# Out:
# Text(0, 0.5, 'estados teleportados')

# %%
#Qubits descartados: ninguno
dfGraf = pd.concat([df36a['Discarded qubits'],df36b['Discarded qubits'],
                                         df37a['Discarded qubits'],df37b['Discarded qubits']],axis=1)

dfGraf.columns=['Demanda alta - Oldest','Demanda baja - Oldest','Demanda alta - Newest','Demanda baja - Newest']
fig = plt.figure(figsize=(6,3))
_ = dfGraf['Demanda alta - Oldest'].plot(color='b',legend='True')
_ = dfGraf['Demanda baja - Oldest'].plot(color='r',legend='True')
_ = dfGraf['Demanda alta - Newest'].plot(color='g',legend='True')
_ = dfGraf['Demanda baja - Newest'].plot(color='y',legend='True')
plt.title('Evolución dqubits descartados con el tiempo de instrucciones')
plt.xlabel('estados teleportados')
plt.ylabel('nanosegundos')

#SEPARAR EN OLDESTY NEWEST, ASÍ NO SE VE
# Out:
# Text(0, 0.5, 'nanosegundos')

# %%
#Tamaño cola: ninguno
dfGraf = pd.concat([df36a['Queue size'],df36b['Queue size'],
                                         df37a['Queue size'],df37b['Queue size']],axis=1)

dfGraf.columns=['Demanda alta - Oldest','Demanda baja - Oldest','Demanda alta - Newest','Demanda baja - Newest']
fig = plt.figure(figsize=(6,3))
_ = dfGraf['Demanda alta - Oldest'].plot(color='b',legend='True')
_ = dfGraf['Demanda baja - Oldest'].plot(color='r',legend='True')
_ = dfGraf['Demanda alta - Newest'].plot(color='g',legend='True')
_ = dfGraf['Demanda baja - Newest'].plot(color='y',legend='True')
plt.title('Evolución tamaño cola con el tiempo de \n ejecución de instrucciones')
plt.xlabel('nanosegundos')
plt.ylabel('qubits encolados')
# Out:
# Text(0, 0.5, 'qubits encolados')

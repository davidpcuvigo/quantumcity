# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

df24 = pd.read_csv('prueba24.csv',delimiter=',')
df24.set_index('distance',inplace=True)

fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(projection = '3d')
ax.set_xlabel('km',labelpad=10)
ax.set_ylabel('nanoseconds',labelpad=20)
ax.set_zlabel('eps',labelpad=20)
ax.set_title('Capacidad frente a distancia extremo a extremo \n y duración e instrucciones')

for time in [10,1000,5000,15000,30000]:
    ax.plot_trisurf(df24[df24['gate time']==time].index,df24[df24['gate time']==time]['valor'],df24[df24['gate time']==time]['EPS'],linewidth=0.2, antialiased=True)
    ax.view_init(elev=10., azim=275)
plt.legend(['10ns','1000ns','5000ns','15000ns','30000ns'],loc="upper right")

plt.show()

#Lo que se ve: Para valores bajos e distancias, 
#el tiempo de ejecución en puertas incluye de forma decisiva en capacidad.
#No así la decoherencia, la capacidad es constante

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#my_cmap = plt.get_cmap('hot')

df24 = pd.read_csv('prueba24.csv',delimiter=',')
df24.set_index('gate time',inplace=True)
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection = '3d')
ax.set_xlabel('\n\nT. instr. (ns)')
ax.set_ylabel('\n\nT1 (ns)')
ax.set_zlabel('eps',labelpad=12)
ax.set_title('Capacidad frente a decoherencia en memorias, duración de instrucciones \n en puertas y distancia E2E')

for distance in [10,50,100,250,500]:
    ax.plot_trisurf(df24[df24['distance']==distance].index,df24[df24['distance']==distance]['valor'],df24[df24['distance']==distance]['EPS'],linewidth=0.2, antialiased=True)
    ax.view_init(elev=2., azim=280)
plt.legend(['10 km','50 km','100 km','250 km','500 km'])
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#my_cmap = plt.get_cmap('hot')

df24 = pd.read_csv('prueba24.csv',delimiter=',')
df24.set_index('gate time',inplace=True)
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection = '3d')
ax.set_xlabel('ns')
ax.set_ylabel('ns')
ax.set_zlabel('fidelidad',labelpad=12)
ax.set_title('Capacidad frente a duración de instrucciones \n en puertas y distancia E2E')

for distance in [10,50,100,250,500]:
    ax.plot_trisurf(df24[df24['distance']==distance].index,df24[df24['distance']==distance]['valor'],df24[df24['distance']==distance]['Mean time'],linewidth=0.2, antialiased=True)
    ax.view_init(elev=5., azim=280)
plt.legend(['10 km','50 km','100 km','250 km','500 km'])
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#my_cmap = plt.get_cmap('hot')

df24 = pd.read_csv('prueba24.csv',delimiter=',')
df24.set_index('gate time',inplace=True)
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection = '3d')
ax.set_xlabel('ns', labelpad=20)
ax.set_ylabel('ns', labelpad=20)
ax.set_zlabel('eps',labelpad=12)
ax.set_title('Fidelidad frente a duración de instrucciones \n en puertas y distancia E2E')

for distance in [10,50,100,250,500]:
    ax.plot_trisurf(df24[df24['distance']==distance].index,df24[df24['distance']==distance]['valor'],df24[df24['distance']==distance]['Mean fidel'],linewidth=0.2, antialiased=True)
    ax.view_init(elev=2., azim=0)
plt.legend(['10km','50km','100km','250km','500km'])
plt.show()

# %%
df24[df24['distance']==10]['valor']
np.lo
# Out:
# gate time
# 1000    1.000000e+06
# 1000    1.072267e+06
# 1000    1.149757e+06
# 1000    1.232847e+06
# 1000    1.321941e+06
#             ...
# 5000    7.564633e+08
# 5000    8.111308e+08
# 5000    8.697490e+08
# 5000    9.326033e+08
# 5000    1.000000e+09
# Name: valor, Length: 500, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import matplotlib.ticker as mticker

# My axis should display 10⁻¹ but you can switch to e-notation 1.00e+01
def log_tick_formatter(val, pos=None):
    print(val)
    return f"$10^{{{int(val)}}}$"  # remove int() if you don't use MaxNLocator
    # return f"{10**val:.2e}"      # e-Notation

df24 = pd.read_csv('prueba24.csv',delimiter=',')
#df24['GateTime']=np.log(df24['gate time'])
df24.set_index('gate time',inplace=True)
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection = '3d')
ax.set_xlabel('ns', labelpad=20)
ax.set_ylabel('ns', labelpad=20)
ax.set_zlabel('Fidelidad',labelpad=12)
ax.set_title('Fidelidad frente a decoherencia en memorias, duración de instrucciones \n en puertas y distancia E2E')

for distance in [10,50,100,250,500]:
    ax.plot_trisurf(df24[df24['distance']==distance].index,np.log(df24[df24['distance']==distance]['valor']),df24[df24['distance']==distance]['Mean fidel'],linewidth=0.2, antialiased=True)
    ax.view_init(elev=5., azim=-10)
    #ax.yaxis.set_major_formatter(mticker.FuncFormatter(log_tick_formatter))
    #ax.yaxis.set_major_locator(mticker.MaxNLocator(integer=True))
    #ax.yscale("log")
plt.legend(['10 km','50 km','100 km','250 km','500 km'])
plt.show()

# %%
#Esta figura solo es para generar la escala en el eje X
fig = plt.figure(figsize=(7,10))

dfGraf = df24[df24['distance']==500]
dfGraf.set_index('valor',inplace=True)
_ = dfGraf['Mean fidel'].plot(color='b',linestyle='dashed',legend='True',logx=True)

# %%
dfGraf = pd.concat([df15a['Mean fidel'],df15b['Mean fidel'],
                                         df16a['Mean fidel'],df16b['Mean fidel'],
                                        df17a['Mean fidel'],df17b['Mean fidel']],axis=1)
dfGraf.columns=['10km - 1 switch','100km - 1 switch','10km - 3 switches','100km - 3 switches','10km - 5 switches','100km - 5 switches']

# %%
import plotly.graph_objects as go
import numpy as np
import pandas as pd
np.random.seed(1)
df24 = pd.read_csv('prueba24.csv',delimiter=',')
df24.set_index('gate time',inplace=True)


layout = go.Layout(
    autosize=False,
    width=800,
    height=700,
    title='Prueba de Juan',
    xaxis=go.layout.XAxis(linecolor="black", linewidth=1, mirror=True),
    yaxis=go.layout.YAxis(type="log",linecolor="black", linewidth=1, mirror=True),
    margin=go.layout.Margin(l=50, r=50, b=100, t=100, pad=4),
)

x10 = list(df24[df24['distance']==10].index.values)
y10 = list(np.log(df24[df24['distance']==10]['valor']).values)
z10 = list(df24[df24['distance']==10]['Mean fidel'].values)
x50 = list(df24[df24['distance']==50].index.values)
y50 = list(np.log(df24[df24['distance']==50]['valor']).values)
z50 = list(df24[df24['distance']==50]['Mean fidel'].values)
x100 = list(df24[df24['distance']==100].index.values)
y100 = list(np.log(df24[df24['distance']==100]['valor']).values)
z100 = list(df24[df24['distance']==100]['Mean fidel'].values)
x250 = list(df24[df24['distance']==250].index.values)
y250 = list(np.log(df24[df24['distance']==250]['valor']).values)
z250 = list(df24[df24['distance']==250]['Mean fidel'].values)
x500 = list(df24[df24['distance']==500].index.values)
y500 = list(np.log(df24[df24['distance']==500]['valor']).values)
z500 = list(df24[df24['distance']==500]['Mean fidel'].values)



fig = go.Figure(data=
                [go.Mesh3d(x=x10,y=y10,z=z10,opacity=1),
                go.Mesh3d(x=x50,y=y50,z=z50,opacity=1),
                 go.Mesh3d(x=x100,y=y100,z=z100,opacity=1),
                  go.Mesh3d(x=x250,y=y250,z=z250,opacity=1),
                  go.Mesh3d(x=x500,y=y500,z=z500,opacity=1)
                ]
                ,layout=layout)
'''
,color='rgba(244,22,100,0.6)'
fig = go.Figure(data=[
    go.Surface(z=z)
])

fig.update_layout(title='Mt Bruno Elevation', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))


fig.update_layout(
    scene = dict(
        xaxis = dict(nticks=4, range=[-100,100],),
                     yaxis = dict(nticks=4, range=[-50,100],),
                     zaxis = dict(nticks=4, range=[-100,100],),),
    width=700,
    margin=dict(r=20, l=10, b=10, t=10))
'''


fig.show()
